# %% [markdown]
# ## District wise crime committed against Women_2014

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib inline

# %% [markdown]
# ### Importing the dataset

# %%
dataset=pd.read_csv("C:\\Users\\Ankan\\Documents\\Dataset\\NCRB crime records\\crime\\42_District_wise_crimes_committed_against_women_2014.csv")

# %%
dataset.head()
# Out:
#        States/UTs          District  Year  Rape  Custodial Rape  \
# 0  Andhra Pradesh         Anantapur  2014    35               0
# 1  Andhra Pradesh          Chittoor  2014    32               0
# 2  Andhra Pradesh          Cuddapah  2014    28               0
# 3  Andhra Pradesh     East Godavari  2014    85               0
# 4  Andhra Pradesh  Guntakal Railway  2014     0               0
#
#    Custodial_Gang Rape  Custodial_Other Rape  Rape other than Custodial  \
# 0                    0                     0                         35
# 1                    0                     0                         32
# 2                    0                     0                         28
# 3                    0                     0                         85
# 4                    0                     0                          0
#
#    Rape_Gang Rape  Rape_Others  ...  Commission of Sati Prevention Act, 1987  \
# 0               0           35  ...                                        0
# 1               1           31  ...                                        0
# 2               0           28  ...                                        0
# 3               0           85  ...                                        0
# 4               0            0  ...                                        0
#
#    Protection of Women from Domestic Violence Act, 2005  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Immoral Traffic Prevention Act  ITP Under Section 5  ITP Under Section 6  \
# 0                               0                    0                    0
# 1                               4                    4                    0
# 2                               5                    0                    0
# 3                              16                    0                    0
# 4                               0                    0                    0
#
#    ITP Under Section 7  ITP Under Section 8  ITP Under Other Sections  \
# 0                    0                    0                         0
# 1                    0                    0                         0
# 2                    0                    0                         5
# 3                    0                    0                        16
# 4                    0                    0                         0
#
#    Other SLL Crimes against Women  Total Crimes against Women
# 0                               0                        1097
# 1                               0                         607
# 2                               0                         609
# 3                               0                        1277
# 4                               0                           4
#
# [5 rows x 62 columns]

# %% [markdown]
# ### Starting Exploratory data Analysis

# %%
dataset.isnull().sum()
# Out:
# States/UTs                        0
# District                          0
# Year                              0
# Rape                              0
# Custodial Rape                    0
#                                  ..
# ITP Under Section 7               0
# ITP Under Section 8               0
# ITP Under Other Sections          0
# Other SLL Crimes against Women    0
# Total Crimes against Women        0
# Length: 62, dtype: int64

# %%
list_of_types=list(dataset)

# %% [markdown]
# ### Data Analysis on Rape Cases

# %%
# Choosing column with only Rape Crimes
import re 
r = re.compile(".*Rape.*")
Rape_Crime=list(filter(r.match, list_of_types))

# %%
data_with_rape_cases=dataset[["States/UTs","District","Year"]].join(dataset[Rape_Crime])

# %%
data_with_rape_cases["Year"].unique()
# Out:
# array([2014], dtype=int64)

# %%
# Dropping Year
data_with_rape_cases.drop(columns=["Year"],inplace=True)

# %%
data_with_rape_cases
# Out:
#          States/UTs          District  Rape  Custodial Rape  \
# 0    Andhra Pradesh         Anantapur    35               0
# 1    Andhra Pradesh          Chittoor    32               0
# 2    Andhra Pradesh          Cuddapah    28               0
# 3    Andhra Pradesh     East Godavari    85               0
# 4    Andhra Pradesh  Guntakal Railway     0               0
# ..              ...               ...   ...             ...
# 832     Lakshadweep       Lakshadweep     1               0
# 833     Lakshadweep             Total     1               0
# 834      Puducherry          Karaikal     3               0
# 835      Puducherry        Puducherry     7               1
# 836      Puducherry             Total    10               1
#
#      Custodial_Gang Rape  Custodial_Other Rape  Rape other than Custodial  \
# 0                      0                     0                         35
# 1                      0                     0                         32
# 2                      0                     0                         28
# 3                      0                     0                         85
# 4                      0                     0                          0
# ..                   ...                   ...                        ...
# 832                    0                     0                          1
# 833                    0                     0                          1
# 834                    0                     0                          3
# 835                    0                     1                          6
# 836                    0                     1                          9
#
#      Rape_Gang Rape  Rape_Others  Attempt to commit Rape
# 0                 0           35                       1
# 1                 1           31                       0
# 2                 0           28                       4
# 3                 0           85                      18
# 4                 0            0                       0
# ..              ...          ...                     ...
# 832               0            1                       0
# 833               0            1                       0
# 834               0            3                       0
# 835               1            5                       0
# 836               1            8                       0
#
# [837 rows x 10 columns]

# %%
data_statewise=data_with_rape_cases.groupby(["States/UTs"],as_index=False).sum()

# %%
data_statewise
# Out:
#            States/UTs   Rape  Custodial Rape  Custodial_Gang Rape  \
# 0         A&N Islands     64               0                    0
# 1      Andhra Pradesh   1922               0                    0
# 2   Arunachal Pradesh    166               8                    0
# 3               Assam   3960               0                    0
# 4               Bihar   2254               0                    0
# 5          Chandigarh    118               0                    0
# 6        Chhattisgarh   2872               0                    0
# 7          D&N Haveli     10               0                    0
# 8         Daman & Diu      4               0                    0
# 9            Delhi UT   4192               0                    0
# 10                Goa    190               0                    0
# 11            Gujarat   1682               0                    0
# 12            Haryana   2348               0                    0
# 13   Himachal Pradesh    566               0                    0
# 14    Jammu & Kashmir    662               0                    0
# 15          Jharkhand   2100               0                    0
# 16          Karnataka   2648               0                    0
# 17             Kerala   2694               0                    0
# 18        Lakshadweep      2               0                    0
# 19     Madhya Pradesh  10152               0                    0
# 20        Maharashtra   6876               0                    0
# 21            Manipur    150               0                    0
# 22          Meghalaya    236               0                    0
# 23            Mizoram    240               0                    0
# 24           Nagaland     60               0                    0
# 25             Odisha   3956               0                    0
# 26         Puducherry     20               2                    0
# 27             Punjab   1962               0                    0
# 28          Rajasthan   7518               6                    4
# 29             Sikkim     94               2                    0
# 30         Tamil Nadu    910               0                    0
# 31          Telangana   1958               0                    0
# 32            Tripura    478               0                    0
# 33      Uttar Pradesh   6934             378                   10
# 34        Uttarakhand    540               0                    0
# 35        West Bengal   6818               2                    0
#
#     Custodial_Other Rape  Rape other than Custodial  Rape_Gang Rape  \
# 0                      0                         64               2
# 1                      0                       1922              28
# 2                      8                        158              10
# 3                      0                       3960              46
# 4                      0                       2254              48
# 5                      0                        118               0
# 6                      0                       2872             128
# 7                      0                         10               0
# 8                      0                          4               0
# 9                      0                       4192             294
# 10                     0                        190               4
# 11                     0                       1682              32
# 12                     0                       2348             460
# 13                     0                        566              12
# 14                     0                        662               0
# 15                     0                       2100             104
# 16                     0                       2648              50
# 17                     0                       2694              16
# 18                     0                          2               0
# 19                     0                      10152             568
# 20                     0                       6876             252
# 21                     0                        150               0
# 22                     0                        236               6
# 23                     0                        240              14
# 24                     0                         60               8
# 25                     0                       3956             164
# 26                     2                         18               2
# 27                     0                       1962              48
# 28                     2                       7512             828
# 29                     2                         92               2
# 30                     0                        910               4
# 31                     0                       1958              28
# 32                     0                        478              30
# 33                   368                       6556            1146
# 34                     0                        540               2
# 35                     2                       6816             368
#
#     Rape_Others  Attempt to commit Rape
# 0            62                       0
# 1          1894                     330
# 2           148                      20
# 3          3914                     454
# 4          2206                     968
# 5           118                      12
# 6          2744                      42
# 7            10                       0
# 8             4                       0
# 9          3898                     140
# 10          186                       4
# 11         1650                      12
# 12         1888                     272
# 13          554                      10
# 14          662                      40
# 15         1996                     416
# 16         2598                      44
# 17         2678                      72
# 18            2                       0
# 19         9584                     112
# 20         6624                      30
# 21          150                       2
# 22          230                      52
# 23          226                       2
# 24           52                       6
# 25         3792                      66
# 26           16                       0
# 27         1914                     308
# 28         6684                     746
# 29           90                      18
# 30          906                      32
# 31         1930                     146
# 32          448                      70
# 33         5410                     648
# 34          538                      82
# 35         6448                    3464

# %%
list(data_statewise)
# Out:
# ['States/UTs',
#  'Rape',
#  'Custodial Rape',
#  'Custodial_Gang Rape',
#  'Custodial_Other Rape',
#  'Rape other than Custodial',
#  'Rape_Gang Rape',
#  'Rape_Others',
#  'Attempt to commit Rape']

# %%
sns.set(style="dark")
for i in Rape_Crime:
    plt.figure(figsize=(50,15))
    plt.xlabel("States/UTs", fontsize=40)
    plt.ylabel(i, fontsize=40)
    plt.xticks(rotation=90,fontsize=30)
    plt.yticks(rotation=0,fontsize=20)
    sns.barplot(x="States/UTs",y=i,data=data_statewise)

# %%
# Adding a new column to calculate total rape cases Statewise
data_statewise["Total_Rape"]=data_statewise.iloc[:,1:].sum(axis=1)

# %%
type(data_statewise)
# Out:
# pandas.core.frame.DataFrame

# %%
# Plotting with total number of Rapes Statewise
plt.figure(figsize=(50,15))
plt.xlabel("States/UTs", fontsize=40)
plt.ylabel("Total_Rape", fontsize=40)
plt.xticks(rotation=90,fontsize=30)
plt.yticks(rotation=0,fontsize=20)
sns.barplot(x="States/UTs",y="Total_Rape",data=data_statewise)

# %% [markdown]
# ### Disclaimer: It doesnot mean to offend anyone
# ### I just want to see correlation between crimes and False allegations

# %%
# Focusing of Attempt to commit Rape
# Plotting with total number of Rapes Statewise
plt.figure(figsize=(50,15))
plt.xlabel("States/UTs", fontsize=40)
plt.ylabel("Total_Rape", fontsize=40)
plt.xticks(rotation=90,fontsize=30)
plt.yticks(rotation=0,fontsize=20)
sns.barplot(x="States/UTs",y="Attempt to commit Rape",data=data_statewise)

# %%
# Total Rape without Attempt to commit Rape
# Adding a new column to calculate total rape cases Statewise
data_statewise["Total_Rape_excluding_attempt"]=data_statewise.iloc[:,1:-1].sum(axis=1)

# %%
# Focusing of Attempt to commit Rape
# Plotting with total number of Rapes Statewise
plt.figure(figsize=(50,15))
plt.xlabel("States/UTs", fontsize=40)
plt.ylabel("Total_Rape_excluding_attempt", fontsize=40)
plt.xticks(rotation=90,fontsize=30)
plt.yticks(rotation=0,fontsize=20)
sns.barplot(x="States/UTs",y="Total_Rape_excluding_attempt",data=data_statewise)

# %%
# These Visualisation will be updated when i will get official data of False rape accusation statewise of 2014
# If anyone have it please give a link

# %%
# Next i will find the literary rate statewise and then district wise. Does education impact these social factors
# Then filter out with female literary rate

# %%
# Next i will correlate with states with general criminal activity like theft,dacoity,arson etc
# Government policies in favour of women effects the crime rate

# %%
# A lot to be analysed in the dataset
